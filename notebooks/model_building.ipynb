# %%
import os ,sys
sys.path.append(os.path.abspath('../scripts'))

# %%
import pandas as pd

# %%
import model_building as md

# %%
df_oil = pd.read_csv('../data/oildata.csv')

# %%
df_oil.head()
# Out:
#          Date  Price  Price_Returns
# 0  1987-05-20  18.63            NaN
# 1  1987-05-21  18.45      -0.009662
# 2  1987-05-22  18.55       0.005420
# 3  1987-05-25  18.60       0.002695
# 4  1987-05-26  18.63       0.001613

# %%
md.price_trend_seasonality(df_oil)
# Out:
# INFO:model_building:Using ARIMA to capture baseline trends and seasonal patterns.
# INFO:model_building:Fitting ARIMA model
# c:\Users\bekib\Desktop\10ACADAMY\WEEK-TEN\week-10\.week-10\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ns will be used.
#   self._init_dates(dates, freq)
# c:\Users\bekib\Desktop\10ACADAMY\WEEK-TEN\week-10\.week-10\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ns will be used.
#   self._init_dates(dates, freq)
# c:\Users\bekib\Desktop\10ACADAMY\WEEK-TEN\week-10\.week-10\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ns will be used.
#   self._init_dates(dates, freq)
# INFO:model_building:Generating ARIMA forecast
# INFO:model_building:Plotting forecast

# %%
md.garch_model_for_volatility(df_oil)
# Out:
# INFO:model_building:GARCH model to capture volatility especially during events and high-uncertinity periods
# INFO:model_building:fit the arch model
# c:\Users\bekib\Desktop\10ACADAMY\WEEK-TEN\week-10\.week-10\Lib\site-packages\arch\univariate\base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0006377. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# INFO:model_building:plot volatility
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 2334841709.537296
# Iteration:      2,   Func. Count:     18,   Neg. LLF: -22203.304018635426
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -22203.30402933976
#             Iterations: 6
# ...
